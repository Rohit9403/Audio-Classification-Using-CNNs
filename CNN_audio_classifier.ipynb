# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohit9403/Audio-Classification-Using-CNNs/blob/master/CNN_audio_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dataset Preprocessing

# %%
# !wget http://opihi.cs.uvic.ca/sound/genres.tar.gz
# Out:
# --2020-02-29 17:56:55--  http://opihi.cs.uvic.ca/sound/genres.tar.gz
# Resolving opihi.cs.uvic.ca (opihi.cs.uvic.ca)... 142.104.68.135
# Connecting to opihi.cs.uvic.ca (opihi.cs.uvic.ca)|142.104.68.135|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1225571541 (1.1G) [application/x-gzip]
# Saving to: ‘genres.tar.gz’
#
# genres.tar.gz       100%[===================>]   1.14G  1007KB/s    in 20m 56s
#
# 2020-02-29 18:17:52 (953 KB/s) - ‘genres.tar.gz’ saved [1225571541/1225571541]

# %%
# !ls
# Out:
# drive  genres.tar.gz  sample_data

# %%
# !tar -xf genres.tar.gz

# %%
# !ls
# Out:
# drive  genres  genres.tar.gz  sample_data

# %%
# %cd genres
# Out:
# /content/genres

# %%
# !ls
# Out:
# bextract_single.mf  classical  country	hi.mf	  ja.mf  metal	reggae	ro.mf
# bl.mf		    cl.mf      di.mf	hiphop	  jazz	 po.mf	re.mf
# blues		    co.mf      disco	input.mf  me.mf  pop	rock

# %% [markdown]
# #Function for extracting MFCC

# %%
import json
import os
import math
import librosa

DATASET_PATH = "/content/genres"
JSON_PATH = "data_10.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION


def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		# load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, d+1))
    

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
        
        
if __name__ == "__main__":
    save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
    save_mfcc("/content/drive/My Drive/Colab Data/Two_Feet_-_Go_Fuck_Yourself (online-audio-converter.com).wav",
              "data_1.json")
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/genres/blues/blues.00080.wav, segment:10
# /content/genres/blues/blues.00022.wav, segment:1
# /content/genres/blues/blues.00022.wav, segment:2
# /content/genres/blues/blues.00022.wav, segment:3
# /content/genres/blues/blues.00022.wav, segment:4
# /content/genres/blues/blues.00022.wav, segment:5
# /content/genres/blues/blues.00022.wav, segment:6
# /content/genres/blues/blues.00022.wav, segment:7
# /content/genres/blues/blues.00022.wav, segment:8
# /content/genres/blues/blues.00022.wav, segment:9
# /content/genres/blues/blues.00022.wav, segment:10
# /content/genres/blues/blues.00007.wav, segment:1
# /content/genres/blues/blues.00007.wav, segment:2
# /content/genres/blues/blues.00007.wav, segment:3
# /content/genres/blues/blues.00007.wav, segment:4
# /content/genres/blues/blues.00007.wav, segment:5
# /content/genres/blues/blues.00007.wav, segment:6
# /content/genres/blues/blues.00007.wav, segment:7
# /content/genres/blues/blues.00007.wav, segment:8
# /content/genres/blues/blues.00007.wav, segment:9
# /content/genres/blues/blues.00007.wav, segment:10
# /content/genres/blues/blues.00000.wav, segment:1
# /content/genres/blues/blues.00000.wav, segment:2
# /content/genres/blues/blues.00000.wav, segment:3
# /content/genres/blues/blues.00000.wav, segment:4
# /content/genres/blues/blues.00000.wav, segment:5
# /content/genres/blues/blues.00000.wav, segment:6
# /content/genres/blues/blues.00000.wav, segment:7
# /content/genres/blues/blues.00000.wav, segment:8
# /content/genres/blues/blues.00000.wav, segment:9
# /content/genres/blues/blues.00000.wav, segment:10
# /content/genres/blues/blues.00093.wav, segment:1
# /content/genres/blues/blues.00093.wav, segment:2
# /content/genres/blues/blues.00093.wav, segment:3
# /content/genres/blues/blues.00093.wav, segment:4
# /content/genres/blues/blues.00093.wav, segment:5
# /content/genres/blues/blues.00093.wav, segment:6
# /content/genres/blues/blues.00093.wav, segment:7
# /content/genres/blues/blues.00093.wav, segment:8
# /content/genres/blues/blues.00093.wav, segment:9
# /content/genres/blues/blues.00093.wav, segment:10
# /content/genres/blues/blues.00019.wav, segment:1
# /content/genres/blues/blues.00019.wav, segment:2
# /content/genres/blues/blues.00019.wav, segment:3
# /content/genres/blues/blues.00019.wav, segment:4
# /content/genres/blues/blues.00019.wav, segment:5
# /content/genres/blues/blues.00019.wav, segment:6
# /content/genres/blues/blues.00019.wav, segment:7
# /content/genres/blues/blues.00019.wav, segment:8
# /content/genres/blues/blues.00019.wav, segment:9
# /content/genres/blues/blues.00019.wav, segment:10
# /content/genres/blues/blues.00008.wav, segment:1
# /content/genres/blues/blues.00008.wav, segment:2
# /content/genres/blues/blues.00008.wav, segment:3
# /content/genres/blues/blues.00008.wav, segment:4
# /content/genres/blues/blues.00008.wav, segment:5
# /content/genres/blues/blues.00008.wav, segment:6
# /content/genres/blues/blues.00008.wav, segment:7
# /content/genres/blues/blues.00008.wav, segment:8
# /content/genres/blues/blues.00008.wav, segment:9
# /content/genres/blues/blues.00008.wav, segment:10
# /content/genres/blues/blues.00038.wav, segment:1
# /content/genres/blues/blues.00038.wav, segment:2
# /content/genres/blues/blues.00038.wav, segment:3
# /content/genres/blues/blues.00038.wav, segment:4
# /content/genres/blues/blues.00038.wav, segment:5
# /content/genres/blues/blues.00038.wav, segment:6
# /content/genres/blues/blues.00038.wav, segment:7
# /content/genres/blues/blues.00038.wav, segment:8
# /content/genres/blues/blues.00038.wav, segment:9
# /content/genres/blues/blues.00038.wav, segment:10
# /content/genres/blues/blues.00023.wav, segment:1
# /content/genres/blues/blues.00023.wav, segment:2
# /content/genres/blues/blues.00023.wav, segment:3
# /content/genres/blues/blues.00023.wav, segment:4
# /content/genres/blues/blues.00023.wav, segment:5
# /content/genres/blues/blues.00023.wav, segment:6
# /content/genres/blues/blues.00023.wav, segment:7
# /content/genres/blues/blues.00023.wav, segment:8
# /content/genres/blues/blues.00023.wav, segment:9
# /content/genres/blues/blues.00023.wav, segment:10
# /content/genres/blues/blues.00066.wav, segment:1
# /content/genres/blues/blues.00066.wav, segment:2
# /content/genres/blues/blues.00066.wav, segment:3
# /content/genres/blues/blues.00066.wav, segment:4
# /content/genres/blues/blues.00066.wav, segment:5
# /content/genres/blues/blues.00066.wav, segment:6
# /content/genres/blues/blues.00066.wav, segment:7
# /content/genres/blues/blues.00066.wav, segment:8
# /content/genres/blues/blues.00066.wav, segment:9
# /content/genres/blues/blues.00066.wav, segment:10
# /content/genres/blues/blues.00045.wav, segment:1
# /content/genres/blues/blues.00045.wav, segment:2
# /content/genres/blues/blues.00045.wav, segment:3
# /content/genres/blues/blues.00045.wav, segment:4
# /content/genres/blues/blues.00045.wav, segment:5
# /content/genres/blues/blues.00045.wav, segment:6
# /content/genres/blues/blues.00045.wav, segment:7
# /content/genres/blues/blues.00045.wav, segment:8
# /content/genres/blues/blues.00045.wav, segment:9
# /content/genres/blues/blues.00045.wav, segment:10
# /content/genres/blues/blues.00050.wav, segment:1
# /content/genres/blues/blues.00050.wav, segment:2
# /content/genres/blues/blues.00050.wav, segment:3
# /content/genres/blues/blues.00050.wav, segment:4
# /content/genres/blues/blues.00050.wav, segment:5
# /content/genres/blues/blues.00050.wav, segment:6
# /content/genres/blues/blues.00050.wav, segment:7
# /content/genres/blues/blues.00050.wav, segment:8
# /content/genres/blues/blues.00050.wav, segment:9
# /content/genres/blues/blues.00050.wav, segment:10
# /content/genres/blues/blues.00070.wav, segment:1
# /content/genres/blues/blues.00070.wav, segment:2
# /content/genres/blues/blues.00070.wav, segment:3
# /content/genres/blues/blues.00070.wav, segment:4
# /content/genres/blues/blues.00070.wav, segment:5
# /content/genres/blues/blues.00070.wav, segment:6
# /content/genres/blues/blues.00070.wav, segment:7
# /content/genres/blues/blues.00070.wav, segment:8
# /content/genres/blues/blues.00070.wav, segment:9
# /content/genres/blues/blues.00070.wav, segment:10
# /content/genres/blues/blues.00060.wav, segment:1
# /content/genres/blues/blues.00060.wav, segment:2
# /content/genres/blues/blues.00060.wav, segment:3
# /content/genres/blues/blues.00060.wav, segment:4
# /content/genres/blues/blues.00060.wav, segment:5
# /content/genres/blues/blues.00060.wav, segment:6
# /content/genres/blues/blues.00060.wav, segment:7
# /content/genres/blues/blues.00060.wav, segment:8
# /content/genres/blues/blues.00060.wav, segment:9
# /content/genres/blues/blues.00060.wav, segment:10
# /content/genres/blues/blues.00085.wav, segment:1
# /content/genres/blues/blues.00085.wav, segment:2
# /content/genres/blues/blues.00085.wav, segment:3
# /content/genres/blues/blues.00085.wav, segment:4
# /content/genres/blues/blues.00085.wav, segment:5
# /content/genres/blues/blues.00085.wav, segment:6
# /content/genres/blues/blues.00085.wav, segment:7
# /content/genres/blues/blues.00085.wav, segment:8
# /content/genres/blues/blues.00085.wav, segment:9
# /content/genres/blues/blues.00085.wav, segment:10
# /content/genres/blues/blues.00071.wav, segment:1
# /content/genres/blues/blues.00071.wav, segment:2
# /content/genres/blues/blues.00071.wav, segment:3
# /content/genres/blues/blues.00071.wav, segment:4
# /content/genres/blues/blues.00071.wav, segment:5
# /content/genres/blues/blues.00071.wav, segment:6
# /content/genres/blues/blues.00071.wav, segment:7
# /content/genres/blues/blues.00071.wav, segment:8
# /content/genres/blues/blues.00071.wav, segment:9
# /content/genres/blues/blues.00071.wav, segment:10
# /content/genres/blues/blues.00088.wav, segment:1
# /content/genres/blues/blues.00088.wav, segment:2
# /content/genres/blues/blues.00088.wav, segment:3
# /content/genres/blues/blues.00088.wav, segment:4
# /content/genres/blues/blues.00088.wav, segment:5
# /content/genres/blues/blues.00088.wav, segment:6
# /content/genres/blues/blues.00088.wav, segment:7
# /content/genres/blues/blues.00088.wav, segment:8
# /content/genres/blues/blues.00088.wav, segment:9
# /content/genres/blues/blues.00088.wav, segment:10
# /content/genres/blues/blues.00089.wav, segment:1
# /content/genres/blues/blues.00089.wav, segment:2
# /content/genres/blues/blues.00089.wav, segment:3
# /content/genres/blues/blues.00089.wav, segment:4
# /content/genres/blues/blues.00089.wav, segment:5
# /content/genres/blues/blues.00089.wav, segment:6
# /content/genres/blues/blues.00089.wav, segment:7
# /content/genres/blues/blues.00089.wav, segment:8
# /content/genres/blues/blues.00089.wav, segment:9
# /content/genres/blues/blues.00089.wav, segment:10
# /content/genres/blues/blues.00062.wav, segment:1
# /content/genres/blues/blues.00062.wav, segment:2
# /content/genres/blues/blues.00062.wav, segment:3
# /content/genres/blues/blues.00062.wav, segment:4
# /content/genres/blues/blues.00062.wav, segment:5
# /content/genres/blues/blues.00062.wav, segment:6
# /content/genres/blues/blues.00062.wav, segment:7
# /content/genres/blues/blues.00062.wav, segment:8
# /content/genres/blues/blues.00062.wav, segment:9
# /content/genres/blues/blues.00062.wav, segment:10
# /content/genres/blues/blues.00059.wav, segment:1
# /content/genres/blues/blues.00059.wav, segment:2
# /content/genres/blues/blues.00059.wav, segment:3
# /content/genres/blues/blues.00059.wav, segment:4
# /content/genres/blues/blues.00059.wav, segment:5
# /content/genres/blues/blues.00059.wav, segment:6
# /content/genres/blues/blues.00059.wav, segment:7
# /content/genres/blues/blues.00059.wav, segment:8
# /content/genres/blues/blues.00059.wav, segment:9
# /content/genres/blues/blues.00059.wav, segment:10
# /content/genres/blues/blues.00048.wav, segment:1
# /content/genres/blues/blues.00048.wav, segment:2
# /content/genres/blues/blues.00048.wav, segment:3
# /content/genres/blues/blues.00048.wav, segment:4
# /content/genres/blues/blues.00048.wav, segment:5
# /content/genres/blues/blues.00048.wav, segment:6
# /content/genres/blues/blues.00048.wav, segment:7
# /content/genres/blues/blues.00048.wav, segment:8
# /content/genres/blues/blues.00048.wav, segment:9
# /content/genres/blues/blues.00048.wav, segment:10
# /content/genres/blues/blues.00017.wav, segment:1
# /content/genres/blues/blues.00017.wav, segment:2
# /content/genres/blues/blues.00017.wav, segment:3
# /content/genres/blues/blues.00017.wav, segment:4
# /content/genres/blues/blues.00017.wav, segment:5
# /content/genres/blues/blues.00017.wav, segment:6
# /content/genres/blues/blues.00017.wav, segment:7
# /content/genres/blues/blues.00017.wav, segment:8
# /content/genres/blues/blues.00017.wav, segment:9
# /content/genres/blues/blues.00017.wav, segment:10
# /content/genres/blues/blues.00084.wav, segment:1
# /content/genres/blues/blues.00084.wav, segment:2
# /content/genres/blues/blues.00084.wav, segment:3
# /content/genres/blues/blues.00084.wav, segment:4
# /content/genres/blues/blues.00084.wav, segment:5
# /content/genres/blues/blues.00084.wav, segment:6
# /content/genres/blues/blues.00084.wav, segment:7
# /content/genres/blues/blues.00084.wav, segment:8
# /content/genres/blues/blues.00084.wav, segment:9
# /content/genres/blues/blues.00084.wav, segment:10
# /content/genres/blues/blues.00081.wav, segment:1
# /content/genres/blues/blues.00081.wav, segment:2
# /content/genres/blues/blues.00081.wav, segment:3
# /content/genres/blues/blues.00081.wav, segment:4
# /content/genres/blues/blues.00081.wav, segment:5
# /content/genres/blues/blues.00081.wav, segment:6
# /content/genres/blues/blues.00081.wav, segment:7
# /content/genres/blues/blues.00081.wav, segment:8
# /content/genres/blues/blues.00081.wav, segment:9
# /content/genres/blues/blues.00081.wav, segment:10
# /content/genres/blues/blues.00087.wav, segment:1
# /content/genres/blues/blues.00087.wav, segment:2
# /content/genres/blues/blues.00087.wav, segment:3
# /content/genres/blues/blues.00087.wav, segment:4
# /content/genres/blues/blues.00087.wav, segment:5
# /content/genres/blues/blues.00087.wav, segment:6
# /content/genres/blues/blues.00087.wav, segment:7
# /content/genres/blues/blues.00087.wav, segment:8
# /content/genres/blues/blues.00087.wav, segment:9
# /content/genres/blues/blues.00087.wav, segment:10
# /content/genres/blues/blues.00006.wav, segment:1
# /content/genres/blues/blues.00006.wav, segment:2
# /content/genres/blues/blues.00006.wav, segment:3
# /content/genres/blues/blues.00006.wav, segment:4
# /content/genres/blues/blues.00006.wav, segment:5
# /content/genres/blues/blues.00006.wav, segment:6
# /content/genres/blues/blues.00006.wav, segment:7
# /content/genres/blues/blues.00006.wav, segment:8
# /content/genres/blues/blues.00006.wav, segment:9
# /content/genres/blues/blues.00006.wav, segment:10
# /content/genres/blues/blues.00009.wav, segment:1
# /content/genres/blues/blues.00009.wav, segment:2
# /content/genres/blues/blues.00009.wav, segment:3
# /content/genres/blues/blues.00009.wav, segment:4
# /content/genres/blues/blues.00009.wav, segment:5
# /content/genres/blues/blues.00009.wav, segment:6
# /content/genres/blues/blues.00009.wav, segment:7
# /content/genres/blues/blues.00009.wav, segment:8
# /content/genres/blues/blues.00009.wav, segment:9
# /content/genres/blues/blues.00009.wav, segment:10
# /content/genres/blues/blues.00092.wav, segment:1
# /content/genres/blues/blues.00092.wav, segment:2
# /content/genres/blues/blues.00092.wav, segment:3
# /content/genres/blues/blues.00092.wav, segment:4
# /content/genres/blues/blues.00092.wav, segment:5
# /content/genres/blues/blues.00092.wav, segment:6
# /content/genres/blues/blues.00092.wav, segment:7
# /content/genres/blues/blues.00092.wav, segment:8
# /content/genres/blues/blues.00092.wav, segment:9
# /content/genres/blues/blues.00092.wav, segment:10
# /content/genres/blues/blues.00033.wav, segment:1
# /content/genres/blues/blues.00033.wav, segment:2
# /content/genres/blues/blues.00033.wav, segment:3
# /content/genres/blues/blues.00033.wav, segment:4
# /content/genres/blues/blues.00033.wav, segment:5
# /content/genres/blues/blues.00033.wav, segment:6
# /content/genres/blues/blues.00033.wav, segment:7
# /content/genres/blues/blues.00033.wav, segment:8
# /content/genres/blues/blues.00033.wav, segment:9
# /content/genres/blues/blues.00033.wav, segment:10
# /content/genres/blues/blues.00003.wav, segment:1
# /content/genres/blues/blues.00003.wav, segment:2
# /content/genres/blues/blues.00003.wav, segment:3
# /content/genres/blues/blues.00003.wav, segment:4
# /content/genres/blues/blues.00003.wav, segment:5
# /content/genres/blues/blues.00003.wav, segment:6
# /content/genres/blues/blues.00003.wav, segment:7
# /content/genres/blues/blues.00003.wav, segment:8
# /content/genres/blues/blues.00003.wav, segment:9
# /content/genres/blues/blues.00003.wav, segment:10
# /content/genres/blues/blues.00021.wav, segment:1
# /content/genres/blues/blues.00021.wav, segment:2
# /content/genres/blues/blues.00021.wav, segment:3
# /content/genres/blues/blues.00021.wav, segment:4
# /content/genres/blues/blues.00021.wav, segment:5
# /content/genres/blues/blues.00021.wav, segment:6
# /content/genres/blues/blues.00021.wav, segment:7
# /content/genres/blues/blues.00021.wav, segment:8
# /content/genres/blues/blues.00021.wav, segment:9
# /content/genres/blues/blues.00021.wav, segment:10
# /content/genres/blues/blues.00053.wav, segment:1
# /content/genres/blues/blues.00053.wav, segment:2
# /content/genres/blues/blues.00053.wav, segment:3
# /content/genres/blues/blues.00053.wav, segment:4
# /content/genres/blues/blues.00053.wav, segment:5
# /content/genres/blues/blues.00053.wav, segment:6
# /content/genres/blues/blues.00053.wav, segment:7
# /content/genres/blues/blues.00053.wav, segment:8
# /content/genres/blues/blues.00053.wav, segment:9
# /content/genres/blues/blues.00053.wav, segment:10
# /content/genres/blues/blues.00018.wav, segment:1
# /content/genres/blues/blues.00018.wav, segment:2
# /content/genres/blues/blues.00018.wav, segment:3
# /content/genres/blues/blues.00018.wav, segment:4
# /content/genres/blues/blues.00018.wav, segment:5
# /content/genres/blues/blues.00018.wav, segment:6
# /content/genres/blues/blues.00018.wav, segment:7
# /content/genres/blues/blues.00018.wav, segment:8
# /content/genres/blues/blues.00018.wav, segment:9
# /content/genres/blues/blues.00018.wav, segment:10
# /content/genres/blues/blues.00076.wav, segment:1
# /content/genres/blues/blues.00076.wav, segment:2
# /content/genres/blues/blues.00076.wav, segment:3
# /content/genres/blues/blues.00076.wav, segment:4
# /content/genres/blues/blues.00076.wav, segment:5
# /content/genres/blues/blues.00076.wav, segment:6
# /content/genres/blues/blues.00076.wav, segment:7
# /content/genres/blues/blues.00076.wav, segment:8
# /content/genres/blues/blues.00076.wav, segment:9
# /content/genres/blues/blues.00076.wav, segment:10
# /content/genres/blues/blues.00065.wav, segment:1
# /content/genres/blues/blues.00065.wav, segment:2
# /content/genres/blues/blues.00065.wav, segment:3
# /content/genres/blues/blues.00065.wav, segment:4
# /content/genres/blues/blues.00065.wav, segment:5
# /content/genres/blues/blues.00065.wav, segment:6
# /content/genres/blues/blues.00065.wav, segment:7
# /content/genres/blues/blues.00065.wav, segment:8
# /content/genres/blues/blues.00065.wav, segment:9
# /content/genres/blues/blues.00065.wav, segment:10
# /content/genres/blues/blues.00029.wav, segment:1
# /content/genres/blues/blues.00029.wav, segment:2
# /content/genres/blues/blues.00029.wav, segment:3
# /content/genres/blues/blues.00029.wav, segment:4
# /content/genres/blues/blues.00029.wav, segment:5
# /content/genres/blues/blues.00029.wav, segment:6
# /content/genres/blues/blues.00029.wav, segment:7
# /content/genres/blues/blues.00029.wav, segment:8
# /content/genres/blues/blues.00029.wav, segment:9
# /content/genres/blues/blues.00029.wav, segment:10
# /content/genres/blues/blues.00083.wav, segment:1
# /content/genres/blues/blues.00083.wav, segment:2
# /content/genres/blues/blues.00083.wav, segment:3
# /content/genres/blues/blues.00083.wav, segment:4
# /content/genres/blues/blues.00083.wav, segment:5
# /content/genres/blues/blues.00083.wav, segment:6
# /content/genres/blues/blues.00083.wav, segment:7
# /content/genres/blues/blues.00083.wav, segment:8
# /content/genres/blues/blues.00083.wav, segment:9
# /content/genres/blues/blues.00083.wav, segment:10
# /content/genres/blues/blues.00073.wav, segment:1
# /content/genres/blues/blues.00073.wav, segment:2
# /content/genres/blues/blues.00073.wav, segment:3
# /content/genres/blues/blues.00073.wav, segment:4
# /content/genres/blues/blues.00073.wav, segment:5
# /content/genres/blues/blues.00073.wav, segment:6
# /content/genres/blues/blues.00073.wav, segment:7
# /content/genres/blues/blues.00073.wav, segment:8
# /content/genres/blues/blues.00073.wav, segment:9
# /content/genres/blues/blues.00073.wav, segment:10
# /content/genres/blues/blues.00055.wav, segment:1
# /content/genres/blues/blues.00055.wav, segment:2
# /content/genres/blues/blues.00055.wav, segment:3
# /content/genres/blues/blues.00055.wav, segment:4
# /content/genres/blues/blues.00055.wav, segment:5
# /content/genres/blues/blues.00055.wav, segment:6
# /content/genres/blues/blues.00055.wav, segment:7
# /content/genres/blues/blues.00055.wav, segment:8
# /content/genres/blues/blues.00055.wav, segment:9
# /content/genres/blues/blues.00055.wav, segment:10
# /content/genres/blues/blues.00067.wav, segment:1
# /content/genres/blues/blues.00067.wav, segment:2
# /content/genres/blues/blues.00067.wav, segment:3
# /content/genres/blues/blues.00067.wav, segment:4
# /content/genres/blues/blues.00067.wav, segment:5
# /content/genres/blues/blues.00067.wav, segment:6
# /content/genres/blues/blues.00067.wav, segment:7
# /content/genres/blues/blues.00067.wav, segment:8
# /content/genres/blues/blues.00067.wav, segment:9
# /content/genres/blues/blues.00067.wav, segment:10
# /content/genres/blues/blues.00031.wav, segment:1
# /content/genres/blues/blues.00031.wav, segment:2
# /content/genres/blues/blues.00031.wav, segment:3
# /content/genres/blues/blues.00031.wav, segment:4
# /content/genres/blues/blues.00031.wav, segment:5
# /content/genres/blues/blues.00031.wav, segment:6
# /content/genres/blues/blues.00031.wav, segment:7
# /content/genres/blues/blues.00031.wav, segment:8
# /content/genres/blues/blues.00031.wav, segment:9
# /content/genres/blues/blues.00031.wav, segment:10
# /content/genres/blues/blues.00069.wav, segment:1
# /content/genres/blues/blues.00069.wav, segment:2
# /content/genres/blues/blues.00069.wav, segment:3
# /content/genres/blues/blues.00069.wav, segment:4
# /content/genres/blues/blues.00069.wav, segment:5
# /content/genres/blues/blues.00069.wav, segment:6
# /content/genres/blues/blues.00069.wav, segment:7
# /content/genres/blues/blues.00069.wav, segment:8
# /content/genres/blues/blues.00069.wav, segment:9
# /content/genres/blues/blues.00069.wav, segment:10
# /content/genres/blues/blues.00004.wav, segment:1
# /content/genres/blues/blues.00004.wav, segment:2
# /content/genres/blues/blues.00004.wav, segment:3
# /content/genres/blues/blues.00004.wav, segment:4
# /content/genres/blues/blues.00004.wav, segment:5
# /content/genres/blues/blues.00004.wav, segment:6
# /content/genres/blues/blues.00004.wav, segment:7
# /content/genres/blues/blues.00004.wav, segment:8
# /content/genres/blues/blues.00004.wav, segment:9
# /content/genres/blues/blues.00004.wav, segment:10
# /content/genres/blues/blues.00072.wav, segment:1
# /content/genres/blues/blues.00072.wav, segment:2
# /content/genres/blues/blues.00072.wav, segment:3
# /content/genres/blues/blues.00072.wav, segment:4
# /content/genres/blues/blues.00072.wav, segment:5
# /content/genres/blues/blues.00072.wav, segment:6
# /content/genres/blues/blues.00072.wav, segment:7
# /content/genres/blues/blues.00072.wav, segment:8
# /content/genres/blues/blues.00072.wav, segment:9
# /content/genres/blues/blues.00072.wav, segment:10
# /content/genres/blues/blues.00086.wav, segment:1
# /content/genres/blues/blues.00086.wav, segment:2
# /content/genres/blues/blues.00086.wav, segment:3
# /content/genres/blues/blues.00086.wav, segment:4
# /content/genres/blues/blues.00086.wav, segment:5
# /content/genres/blues/blues.00086.wav, segment:6
# /content/genres/blues/blues.00086.wav, segment:7
# /content/genres/blues/blues.00086.wav, segment:8
# /content/genres/blues/blues.00086.wav, segment:9
# /content/genres/blues/blues.00086.wav, segment:10
# /content/genres/blues/blues.00063.wav, segment:1
# /content/genres/blues/blues.00063.wav, segment:2
# /content/genres/blues/blues.00063.wav, segment:3
# /content/genres/blues/blues.00063.wav, segment:4
# /content/genres/blues/blues.00063.wav, segment:5
# /content/genres/blues/blues.00063.wav, segment:6
# /content/genres/blues/blues.00063.wav, segment:7
# /content/genres/blues/blues.00063.wav, segment:8
# /content/genres/blues/blues.00063.wav, segment:9
# /content/genres/blues/blues.00063.wav, segment:10
# /content/genres/blues/blues.00095.wav, segment:1
# /content/genres/blues/blues.00095.wav, segment:2
# /content/genres/blues/blues.00095.wav, segment:3
# /content/genres/blues/blues.00095.wav, segment:4
# /content/genres/blues/blues.00095.wav, segment:5
# /content/genres/blues/blues.00095.wav, segment:6
# /content/genres/blues/blues.00095.wav, segment:7
# /content/genres/blues/blues.00095.wav, segment:8
# /content/genres/blues/blues.00095.wav, segment:9
# /content/genres/blues/blues.00095.wav, segment:10
# /content/genres/blues/blues.00034.wav, segment:1
# /content/genres/blues/blues.00034.wav, segment:2
# /content/genres/blues/blues.00034.wav, segment:3
# /content/genres/blues/blues.00034.wav, segment:4
# /content/genres/blues/blues.00034.wav, segment:5
# /content/genres/blues/blues.00034.wav, segment:6
# /content/genres/blues/blues.00034.wav, segment:7
# /content/genres/blues/blues.00034.wav, segment:8
# /content/genres/blues/blues.00034.wav, segment:9
# /content/genres/blues/blues.00034.wav, segment:10
# /content/genres/blues/blues.00026.wav, segment:1
# /content/genres/blues/blues.00026.wav, segment:2
# /content/genres/blues/blues.00026.wav, segment:3
# /content/genres/blues/blues.00026.wav, segment:4
# /content/genres/blues/blues.00026.wav, segment:5
# /content/genres/blues/blues.00026.wav, segment:6
# /content/genres/blues/blues.00026.wav, segment:7
# /content/genres/blues/blues.00026.wav, segment:8
# /content/genres/blues/blues.00026.wav, segment:9
# /content/genres/blues/blues.00026.wav, segment:10
# /content/genres/blues/blues.00082.wav, segment:1
# /content/genres/blues/blues.00082.wav, segment:2
# /content/genres/blues/blues.00082.wav, segment:3
# /content/genres/blues/blues.00082.wav, segment:4
# /content/genres/blues/blues.00082.wav, segment:5
# /content/genres/blues/blues.00082.wav, segment:6
# /content/genres/blues/blues.00082.wav, segment:7
# /content/genres/blues/blues.00082.wav, segment:8
# /content/genres/blues/blues.00082.wav, segment:9
# /content/genres/blues/blues.00082.wav, segment:10
# /content/genres/blues/blues.00051.wav, segment:1
# /content/genres/blues/blues.00051.wav, segment:2
# /content/genres/blues/blues.00051.wav, segment:3
# /content/genres/blues/blues.00051.wav, segment:4
# /content/genres/blues/blues.00051.wav, segment:5
# /content/genres/blues/blues.00051.wav, segment:6
# /content/genres/blues/blues.00051.wav, segment:7
# /content/genres/blues/blues.00051.wav, segment:8
# /content/genres/blues/blues.00051.wav, segment:9
# /content/genres/blues/blues.00051.wav, segment:10
# /content/genres/blues/blues.00039.wav, segment:1
# /content/genres/blues/blues.00039.wav, segment:2
# /content/genres/blues/blues.00039.wav, segment:3
# /content/genres/blues/blues.00039.wav, segment:4
# /content/genres/blues/blues.00039.wav, segment:5
# /content/genres/blues/blues.00039.wav, segment:6
# /content/genres/blues/blues.00039.wav, segment:7
# /content/genres/blues/blues.00039.wav, segment:8
# /content/genres/blues/blues.00039.wav, segment:9
# /content/genres/blues/blues.00039.wav, segment:10
# /content/genres/blues/blues.00035.wav, segment:1
# /content/genres/blues/blues.00035.wav, segment:2
# /content/genres/blues/blues.00035.wav, segment:3
# /content/genres/blues/blues.00035.wav, segment:4
# /content/genres/blues/blues.00035.wav, segment:5
# /content/genres/blues/blues.00035.wav, segment:6
# /content/genres/blues/blues.00035.wav, segment:7
# /content/genres/blues/blues.00035.wav, segment:8
# /content/genres/blues/blues.00035.wav, segment:9
# /content/genres/blues/blues.00035.wav, segment:10
# /content/genres/blues/blues.00075.wav, segment:1
# /content/genres/blues/blues.00075.wav, segment:2
# /content/genres/blues/blues.00075.wav, segment:3
# /content/genres/blues/blues.00075.wav, segment:4
# /content/genres/blues/blues.00075.wav, segment:5
# /content/genres/blues/blues.00075.wav, segment:6
# /content/genres/blues/blues.00075.wav, segment:7
# /content/genres/blues/blues.00075.wav, segment:8
# /content/genres/blues/blues.00075.wav, segment:9
# /content/genres/blues/blues.00075.wav, segment:10
# /content/genres/blues/blues.00024.wav, segment:1
# /content/genres/blues/blues.00024.wav, segment:2
# /content/genres/blues/blues.00024.wav, segment:3
# /content/genres/blues/blues.00024.wav, segment:4
# /content/genres/blues/blues.00024.wav, segment:5
# /content/genres/blues/blues.00024.wav, segment:6
# /content/genres/blues/blues.00024.wav, segment:7
# /content/genres/blues/blues.00024.wav, segment:8
# /content/genres/blues/blues.00024.wav, segment:9
# /content/genres/blues/blues.00024.wav, segment:10
# /content/genres/blues/blues.00005.wav, segment:1
# /content/genres/blues/blues.00005.wav, segment:2
# /content/genres/blues/blues.00005.wav, segment:3
# /content/genres/blues/blues.00005.wav, segment:4
# /content/genres/blues/blues.00005.wav, segment:5
# /content/genres/blues/blues.00005.wav, segment:6
# /content/genres/blues/blues.00005.wav, segment:7
# /content/genres/blues/blues.00005.wav, segment:8
# /content/genres/blues/blues.00005.wav, segment:9
# /content/genres/blues/blues.00005.wav, segment:10
# /content/genres/blues/blues.00098.wav, segment:1
# /content/genres/blues/blues.00098.wav, segment:2
# /content/genres/blues/blues.00098.wav, segment:3
# /content/genres/blues/blues.00098.wav, segment:4
# /content/genres/blues/blues.00098.wav, segment:5
# /content/genres/blues/blues.00098.wav, segment:6
# /content/genres/blues/blues.00098.wav, segment:7
# /content/genres/blues/blues.00098.wav, segment:8
# /content/genres/blues/blues.00098.wav, segment:9
# /content/genres/blues/blues.00098.wav, segment:10
# /content/genres/blues/blues.00043.wav, segment:1
# /content/genres/blues/blues.00043.wav, segment:2
# /content/genres/blues/blues.00043.wav, segment:3
# /content/genres/blues/blues.00043.wav, segment:4
# /content/genres/blues/blues.00043.wav, segment:5
# /content/genres/blues/blues.00043.wav, segment:6
# /content/genres/blues/blues.00043.wav, segment:7
# /content/genres/blues/blues.00043.wav, segment:8
# /content/genres/blues/blues.00043.wav, segment:9
# /content/genres/blues/blues.00043.wav, segment:10
# /content/genres/blues/blues.00090.wav, segment:1
# /content/genres/blues/blues.00090.wav, segment:2
# /content/genres/blues/blues.00090.wav, segment:3
# /content/genres/blues/blues.00090.wav, segment:4
# /content/genres/blues/blues.00090.wav, segment:5
# /content/genres/blues/blues.00090.wav, segment:6
# /content/genres/blues/blues.00090.wav, segment:7
# /content/genres/blues/blues.00090.wav, segment:8
# /content/genres/blues/blues.00090.wav, segment:9
# /content/genres/blues/blues.00090.wav, segment:10
# /content/genres/blues/blues.00002.wav, segment:1
# /content/genres/blues/blues.00002.wav, segment:2
# /content/genres/blues/blues.00002.wav, segment:3
# /content/genres/blues/blues.00002.wav, segment:4
# /content/genres/blues/blues.00002.wav, segment:5
# /content/genres/blues/blues.00002.wav, segment:6
# /content/genres/blues/blues.00002.wav, segment:7
# /content/genres/blues/blues.00002.wav, segment:8
# /content/genres/blues/blues.00002.wav, segment:9
# /content/genres/blues/blues.00002.wav, segment:10
# /content/genres/blues/blues.00077.wav, segment:1
# /content/genres/blues/blues.00077.wav, segment:2
# /content/genres/blues/blues.00077.wav, segment:3
# /content/genres/blues/blues.00077.wav, segment:4
# /content/genres/blues/blues.00077.wav, segment:5
# /content/genres/blues/blues.00077.wav, segment:6
# /content/genres/blues/blues.00077.wav, segment:7
# /content/genres/blues/blues.00077.wav, segment:8
# /content/genres/blues/blues.00077.wav, segment:9
# /content/genres/blues/blues.00077.wav, segment:10
# /content/genres/blues/blues.00012.wav, segment:1
# /content/genres/blues/blues.00012.wav, segment:2
# /content/genres/blues/blues.00012.wav, segment:3
# /content/genres/blues/blues.00012.wav, segment:4
# /content/genres/blues/blues.00012.wav, segment:5
# /content/genres/blues/blues.00012.wav, segment:6
# /content/genres/blues/blues.00012.wav, segment:7
# /content/genres/blues/blues.00012.wav, segment:8
# /content/genres/blues/blues.00012.wav, segment:9
# /content/genres/blues/blues.00012.wav, segment:10
# /content/genres/blues/blues.00068.wav, segment:1
# /content/genres/blues/blues.00068.wav, segment:2
# /content/genres/blues/blues.00068.wav, segment:3
# /content/genres/blues/blues.00068.wav, segment:4
# /content/genres/blues/blues.00068.wav, segment:5
# /content/genres/blues/blues.00068.wav, segment:6
# /content/genres/blues/blues.00068.wav, segment:7
# /content/genres/blues/blues.00068.wav, segment:8
# /content/genres/blues/blues.00068.wav, segment:9
# /content/genres/blues/blues.00068.wav, segment:10
# /content/genres/blues/blues.00040.wav, segment:1
# /content/genres/blues/blues.00040.wav, segment:2
# /content/genres/blues/blues.00040.wav, segment:3
# /content/genres/blues/blues.00040.wav, segment:4
# /content/genres/blues/blues.00040.wav, segment:5
# /content/genres/blues/blues.00040.wav, segment:6
# /content/genres/blues/blues.00040.wav, segment:7
# /content/genres/blues/blues.00040.wav, segment:8
# /content/genres/blues/blues.00040.wav, segment:9
# /content/genres/blues/blues.00040.wav, segment:10
# /content/genres/blues/blues.00028.wav, segment:1
# /content/genres/blues/blues.00028.wav, segment:2
# /content/genres/blues/blues.00028.wav, segment:3
# /content/genres/blues/blues.00028.wav, segment:4
# /content/genres/blues/blues.00028.wav, segment:5
# /content/genres/blues/blues.00028.wav, segment:6
# /content/genres/blues/blues.00028.wav, segment:7
# /content/genres/blues/blues.00028.wav, segment:8
# /content/genres/blues/blues.00028.wav, segment:9
# /content/genres/blues/blues.00028.wav, segment:10
# /content/genres/blues/blues.00025.wav, segment:1
# /content/genres/blues/blues.00025.wav, segment:2
# /content/genres/blues/blues.00025.wav, segment:3
# /content/genres/blues/blues.00025.wav, segment:4
# /content/genres/blues/blues.00025.wav, segment:5
# /content/genres/blues/blues.00025.wav, segment:6
# /content/genres/blues/blues.00025.wav, segment:7
# /content/genres/blues/blues.00025.wav, segment:8
# /content/genres/blues/blues.00025.wav, segment:9
# /content/genres/blues/blues.00025.wav, segment:10
# /content/genres/blues/blues.00036.wav, segment:1
# /content/genres/blues/blues.00036.wav, segment:2
# /content/genres/blues/blues.00036.wav, segment:3
# /content/genres/blues/blues.00036.wav, segment:4
# /content/genres/blues/blues.00036.wav, segment:5
# /content/genres/blues/blues.00036.wav, segment:6
# /content/genres/blues/blues.00036.wav, segment:7
# /content/genres/blues/blues.00036.wav, segment:8
# /content/genres/blues/blues.00036.wav, segment:9
# /content/genres/blues/blues.00036.wav, segment:10
# /content/genres/blues/blues.00049.wav, segment:1
# /content/genres/blues/blues.00049.wav, segment:2
# /content/genres/blues/blues.00049.wav, segment:3
# /content/genres/blues/blues.00049.wav, segment:4
# /content/genres/blues/blues.00049.wav, segment:5
# /content/genres/blues/blues.00049.wav, segment:6
# /content/genres/blues/blues.00049.wav, segment:7
# /content/genres/blues/blues.00049.wav, segment:8
# /content/genres/blues/blues.00049.wav, segment:9
# /content/genres/blues/blues.00049.wav, segment:10
# /content/genres/blues/blues.00042.wav, segment:1
# /content/genres/blues/blues.00042.wav, segment:2
# /content/genres/blues/blues.00042.wav, segment:3
# /content/genres/blues/blues.00042.wav, segment:4
# /content/genres/blues/blues.00042.wav, segment:5
# /content/genres/blues/blues.00042.wav, segment:6
# /content/genres/blues/blues.00042.wav, segment:7
# /content/genres/blues/blues.00042.wav, segment:8
# /content/genres/blues/blues.00042.wav, segment:9
# /content/genres/blues/blues.00042.wav, segment:10
# /content/genres/blues/blues.00079.wav, segment:1
# /content/genres/blues/blues.00079.wav, segment:2
# /content/genres/blues/blues.00079.wav, segment:3
# /content/genres/blues/blues.00079.wav, segment:4
# /content/genres/blues/blues.00079.wav, segment:5
# /content/genres/blues/blues.00079.wav, segment:6
# /content/genres/blues/blues.00079.wav, segment:7
# /content/genres/blues/blues.00079.wav, segment:8
# /content/genres/blues/blues.00079.wav, segment:9
# /content/genres/blues/blues.00079.wav, segment:10
# /content/genres/blues/blues.00054.wav, segment:1
# /content/genres/blues/blues.00054.wav, segment:2
# /content/genres/blues/blues.00054.wav, segment:3
# /content/genres/blues/blues.00054.wav, segment:4
# /content/genres/blues/blues.00054.wav, segment:5
# /content/genres/blues/blues.00054.wav, segment:6
# /content/genres/blues/blues.00054.wav, segment:7
# /content/genres/blues/blues.00054.wav, segment:8
# /content/genres/blues/blues.00054.wav, segment:9
# /content/genres/blues/blues.00054.wav, segment:10
# /content/genres/blues/blues.00014.wav, segment:1
# /content/genres/blues/blues.00014.wav, segment:2
# /content/genres/blues/blues.00014.wav, segment:3
# /content/genres/blues/blues.00014.wav, segment:4
# /content/genres/blues/blues.00014.wav, segment:5
# /content/genres/blues/blues.00014.wav, segment:6
# /content/genres/blues/blues.00014.wav, segment:7
# /content/genres/blues/blues.00014.wav, segment:8
# /content/genres/blues/blues.00014.wav, segment:9
# /content/genres/blues/blues.00014.wav, segment:10
# /content/genres/blues/blues.00032.wav, segment:1
# /content/genres/blues/blues.00032.wav, segment:2
# /content/genres/blues/blues.00032.wav, segment:3
# /content/genres/blues/blues.00032.wav, segment:4
# /content/genres/blues/blues.00032.wav, segment:5
# /content/genres/blues/blues.00032.wav, segment:6
# /content/genres/blues/blues.00032.wav, segment:7
# /content/genres/blues/blues.00032.wav, segment:8
# /content/genres/blues/blues.00032.wav, segment:9
# /content/genres/blues/blues.00032.wav, segment:10
# /content/genres/blues/blues.00074.wav, segment:1
# /content/genres/blues/blues.00074.wav, segment:2
# /content/genres/blues/blues.00074.wav, segment:3
# /content/genres/blues/blues.00074.wav, segment:4
# /content/genres/blues/blues.00074.wav, segment:5
# /content/genres/blues/blues.00074.wav, segment:6
# /content/genres/blues/blues.00074.wav, segment:7
# /content/genres/blues/blues.00074.wav, segment:8
# /content/genres/blues/blues.00074.wav, segment:9
# /content/genres/blues/blues.00074.wav, segment:10
# /content/genres/blues/blues.00096.wav, segment:1
# /content/genres/blues/blues.00096.wav, segment:2
# /content/genres/blues/blues.00096.wav, segment:3
# /content/genres/blues/blues.00096.wav, segment:4
# /content/genres/blues/blues.00096.wav, segment:5
# /content/genres/blues/blues.00096.wav, segment:6
# /content/genres/blues/blues.00096.wav, segment:7
# /content/genres/blues/blues.00096.wav, segment:8
# /content/genres/blues/blues.00096.wav, segment:9
# /content/genres/blues/blues.00096.wav, segment:10
# /content/genres/blues/blues.00027.wav, segment:1
# /content/genres/blues/blues.00027.wav, segment:2
# /content/genres/blues/blues.00027.wav, segment:3
# /content/genres/blues/blues.00027.wav, segment:4
# /content/genres/blues/blues.00027.wav, segment:5
# /content/genres/blues/blues.00027.wav, segment:6
# /content/genres/blues/blues.00027.wav, segment:7
# /content/genres/blues/blues.00027.wav, segment:8
# /content/genres/blues/blues.00027.wav, segment:9
# /content/genres/blues/blues.00027.wav, segment:10
# /content/genres/blues/blues.00046.wav, segment:1
# /content/genres/blues/blues.00046.wav, segment:2
# /content/genres/blues/blues.00046.wav, segment:3
# /content/genres/blues/blues.00046.wav, segment:4
# /content/genres/blues/blues.00046.wav, segment:5
# /content/genres/blues/blues.00046.wav, segment:6
# /content/genres/blues/blues.00046.wav, segment:7
# /content/genres/blues/blues.00046.wav, segment:8
# /content/genres/blues/blues.00046.wav, segment:9
# /content/genres/blues/blues.00046.wav, segment:10
# /content/genres/blues/blues.00047.wav, segment:1
# /content/genres/blues/blues.00047.wav, segment:2
# /content/genres/blues/blues.00047.wav, segment:3
# /content/genres/blues/blues.00047.wav, segment:4
# /content/genres/blues/blues.00047.wav, segment:5
# /content/genres/blues/blues.00047.wav, segment:6
# /content/genres/blues/blues.00047.wav, segment:7
# /content/genres/blues/blues.00047.wav, segment:8
# /content/genres/blues/blues.00047.wav, segment:9
# /content/genres/blues/blues.00047.wav, segment:10
# /content/genres/blues/blues.00064.wav, segment:1
# /content/genres/blues/blues.00064.wav, segment:2
# /content/genres/blues/blues.00064.wav, segment:3
# /content/genres/blues/blues.00064.wav, segment:4
# /content/genres/blues/blues.00064.wav, segment:5
# /content/genres/blues/blues.00064.wav, segment:6
# /content/genres/blues/blues.00064.wav, segment:7
# /content/genres/blues/blues.00064.wav, segment:8
# /content/genres/blues/blues.00064.wav, segment:9
# /content/genres/blues/blues.00064.wav, segment:10
# /content/genres/blues/blues.00061.wav, segment:1
# /content/genres/blues/blues.00061.wav, segment:2
# /content/genres/blues/blues.00061.wav, segment:3
# /content/genres/blues/blues.00061.wav, segment:4
# /content/genres/blues/blues.00061.wav, segment:5
# /content/genres/blues/blues.00061.wav, segment:6
# /content/genres/blues/blues.00061.wav, segment:7
# /content/genres/blues/blues.00061.wav, segment:8
# /content/genres/blues/blues.00061.wav, segment:9
# /content/genres/blues/blues.00061.wav, segment:10
# /content/genres/blues/blues.00011.wav, segment:1
# /content/genres/blues/blues.00011.wav, segment:2
# /content/genres/blues/blues.00011.wav, segment:3
# /content/genres/blues/blues.00011.wav, segment:4
# /content/genres/blues/blues.00011.wav, segment:5
# /content/genres/blues/blues.00011.wav, segment:6
# /content/genres/blues/blues.00011.wav, segment:7
# /content/genres/blues/blues.00011.wav, segment:8
# /content/genres/blues/blues.00011.wav, segment:9
# /content/genres/blues/blues.00011.wav, segment:10
# /content/genres/blues/blues.00056.wav, segment:1
# /content/genres/blues/blues.00056.wav, segment:2
# /content/genres/blues/blues.00056.wav, segment:3
# /content/genres/blues/blues.00056.wav, segment:4
# /content/genres/blues/blues.00056.wav, segment:5
# /content/genres/blues/blues.00056.wav, segment:6
# /content/genres/blues/blues.00056.wav, segment:7
# /content/genres/blues/blues.00056.wav, segment:8
# /content/genres/blues/blues.00056.wav, segment:9
# /content/genres/blues/blues.00056.wav, segment:10
# /content/genres/blues/blues.00099.wav, segment:1
# /content/genres/blues/blues.00099.wav, segment:2
# /content/genres/blues/blues.00099.wav, segment:3
# /content/genres/blues/blues.00099.wav, segment:4
# /content/genres/blues/blues.00099.wav, segment:5
# /content/genres/blues/blues.00099.wav, segment:6
# /content/genres/blues/blues.00099.wav, segment:7
# /content/genres/blues/blues.00099.wav, segment:8
# /content/genres/blues/blues.00099.wav, segment:9
# /content/genres/blues/blues.00099.wav, segment:10
# /content/genres/blues/blues.00057.wav, segment:1
# /content/genres/blues/blues.00057.wav, segment:2
# /content/genres/blues/blues.00057.wav, segment:3
# /content/genres/blues/blues.00057.wav, segment:4
# /content/genres/blues/blues.00057.wav, segment:5
# /content/genres/blues/blues.00057.wav, segment:6
# /content/genres/blues/blues.00057.wav, segment:7
# /content/genres/blues/blues.00057.wav, segment:8
# /content/genres/blues/blues.00057.wav, segment:9
# /content/genres/blues/blues.00057.wav, segment:10
# /content/genres/blues/blues.00058.wav, segment:1
# /content/genres/blues/blues.00058.wav, segment:2
# /content/genres/blues/blues.00058.wav, segment:3
# /content/genres/blues/blues.00058.wav, segment:4
# /content/genres/blues/blues.00058.wav, segment:5
# /content/genres/blues/blues.00058.wav, segment:6
# /content/genres/blues/blues.00058.wav, segment:7
# /content/genres/blues/blues.00058.wav, segment:8
# /content/genres/blues/blues.00058.wav, segment:9
# /content/genres/blues/blues.00058.wav, segment:10
# /content/genres/blues/blues.00052.wav, segment:1
# /content/genres/blues/blues.00052.wav, segment:2
# /content/genres/blues/blues.00052.wav, segment:3
# /content/genres/blues/blues.00052.wav, segment:4
# /content/genres/blues/blues.00052.wav, segment:5
# /content/genres/blues/blues.00052.wav, segment:6
# /content/genres/blues/blues.00052.wav, segment:7
# /content/genres/blues/blues.00052.wav, segment:8
# /content/genres/blues/blues.00052.wav, segment:9
# /content/genres/blues/blues.00052.wav, segment:10
# /content/genres/blues/blues.00091.wav, segment:1
# /content/genres/blues/blues.00091.wav, segment:2
# /content/genres/blues/blues.00091.wav, segment:3
# /content/genres/blues/blues.00091.wav, segment:4
# /content/genres/blues/blues.00091.wav, segment:5
# /content/genres/blues/blues.00091.wav, segment:6
# /content/genres/blues/blues.00091.wav, segment:7
# /content/genres/blues/blues.00091.wav, segment:8
# /content/genres/blues/blues.00091.wav, segment:9
# /content/genres/blues/blues.00091.wav, segment:10
# /content/genres/blues/blues.00094.wav, segment:1
# /content/genres/blues/blues.00094.wav, segment:2
# /content/genres/blues/blues.00094.wav, segment:3
# /content/genres/blues/blues.00094.wav, segment:4
# /content/genres/blues/blues.00094.wav, segment:5
# /content/genres/blues/blues.00094.wav, segment:6
# /content/genres/blues/blues.00094.wav, segment:7
# /content/genres/blues/blues.00094.wav, segment:8
# /content/genres/blues/blues.00094.wav, segment:9
# /content/genres/blues/blues.00094.wav, segment:10
# /content/genres/blues/blues.00030.wav, segment:1
# /content/genres/blues/blues.00030.wav, segment:2
# /content/genres/blues/blues.00030.wav, segment:3
# /content/genres/blues/blues.00030.wav, segment:4
# /content/genres/blues/blues.00030.wav, segment:5
# /content/genres/blues/blues.00030.wav, segment:6
# /content/genres/blues/blues.00030.wav, segment:7
# /content/genres/blues/blues.00030.wav, segment:8
# /content/genres/blues/blues.00030.wav, segment:9
# /content/genres/blues/blues.00030.wav, segment:10
# /content/genres/blues/blues.00016.wav, segment:1
# /content/genres/blues/blues.00016.wav, segment:2
# /content/genres/blues/blues.00016.wav, segment:3
# /content/genres/blues/blues.00016.wav, segment:4
# /content/genres/blues/blues.00016.wav, segment:5
# /content/genres/blues/blues.00016.wav, segment:6
# /content/genres/blues/blues.00016.wav, segment:7
# /content/genres/blues/blues.00016.wav, segment:8
# /content/genres/blues/blues.00016.wav, segment:9
# /content/genres/blues/blues.00016.wav, segment:10
# /content/genres/blues/blues.00097.wav, segment:1
# /content/genres/blues/blues.00097.wav, segment:2
# /content/genres/blues/blues.00097.wav, segment:3
# /content/genres/blues/blues.00097.wav, segment:4
# /content/genres/blues/blues.00097.wav, segment:5
# /content/genres/blues/blues.00097.wav, segment:6
# /content/genres/blues/blues.00097.wav, segment:7
# /content/genres/blues/blues.00097.wav, segment:8
# /content/genres/blues/blues.00097.wav, segment:9
# /content/genres/blues/blues.00097.wav, segment:10
# /content/genres/blues/blues.00001.wav, segment:1
# /content/genres/blues/blues.00001.wav, segment:2
# /content/genres/blues/blues.00001.wav, segment:3
# /content/genres/blues/blues.00001.wav, segment:4
# /content/genres/blues/blues.00001.wav, segment:5
# /content/genres/blues/blues.00001.wav, segment:6
# /content/genres/blues/blues.00001.wav, segment:7
# /content/genres/blues/blues.00001.wav, segment:8
# /content/genres/blues/blues.00001.wav, segment:9
# /content/genres/blues/blues.00001.wav, segment:10
# /content/genres/blues/blues.00041.wav, segment:1
# /content/genres/blues/blues.00041.wav, segment:2
# /content/genres/blues/blues.00041.wav, segment:3
# /content/genres/blues/blues.00041.wav, segment:4
# /content/genres/blues/blues.00041.wav, segment:5
# /content/genres/blues/blues.00041.wav, segment:6
# /content/genres/blues/blues.00041.wav, segment:7
# /content/genres/blues/blues.00041.wav, segment:8
# /content/genres/blues/blues.00041.wav, segment:9
# /content/genres/blues/blues.00041.wav, segment:10
# /content/genres/blues/blues.00078.wav, segment:1
# /content/genres/blues/blues.00078.wav, segment:2
# /content/genres/blues/blues.00078.wav, segment:3
# /content/genres/blues/blues.00078.wav, segment:4
# /content/genres/blues/blues.00078.wav, segment:5
# /content/genres/blues/blues.00078.wav, segment:6
# /content/genres/blues/blues.00078.wav, segment:7
# /content/genres/blues/blues.00078.wav, segment:8
# /content/genres/blues/blues.00078.wav, segment:9
# /content/genres/blues/blues.00078.wav, segment:10
# /content/genres/blues/blues.00013.wav, segment:1
# /content/genres/blues/blues.00013.wav, segment:2
# /content/genres/blues/blues.00013.wav, segment:3
# /content/genres/blues/blues.00013.wav, segment:4
# /content/genres/blues/blues.00013.wav, segment:5
# /content/genres/blues/blues.00013.wav, segment:6
# /content/genres/blues/blues.00013.wav, segment:7
# /content/genres/blues/blues.00013.wav, segment:8
# /content/genres/blues/blues.00013.wav, segment:9
# /content/genres/blues/blues.00013.wav, segment:10
# /content/genres/blues/blues.00037.wav, segment:1
# /content/genres/blues/blues.00037.wav, segment:2
# /content/genres/blues/blues.00037.wav, segment:3
# /content/genres/blues/blues.00037.wav, segment:4
# /content/genres/blues/blues.00037.wav, segment:5
# /content/genres/blues/blues.00037.wav, segment:6
# /content/genres/blues/blues.00037.wav, segment:7
# /content/genres/blues/blues.00037.wav, segment:8
# /content/genres/blues/blues.00037.wav, segment:9
# /content/genres/blues/blues.00037.wav, segment:10
# /content/genres/blues/blues.00015.wav, segment:1
# /content/genres/blues/blues.00015.wav, segment:2
# /content/genres/blues/blues.00015.wav, segment:3
# /content/genres/blues/blues.00015.wav, segment:4
# /content/genres/blues/blues.00015.wav, segment:5
# /content/genres/blues/blues.00015.wav, segment:6
# /content/genres/blues/blues.00015.wav, segment:7
# /content/genres/blues/blues.00015.wav, segment:8
# /content/genres/blues/blues.00015.wav, segment:9
# /content/genres/blues/blues.00015.wav, segment:10
# /content/genres/blues/blues.00010.wav, segment:1
# /content/genres/blues/blues.00010.wav, segment:2
# /content/genres/blues/blues.00010.wav, segment:3
# /content/genres/blues/blues.00010.wav, segment:4
# /content/genres/blues/blues.00010.wav, segment:5
# /content/genres/blues/blues.00010.wav, segment:6
# /content/genres/blues/blues.00010.wav, segment:7
# /content/genres/blues/blues.00010.wav, segment:8
# /content/genres/blues/blues.00010.wav, segment:9
# /content/genres/blues/blues.00010.wav, segment:10
# /content/genres/blues/blues.00044.wav, segment:1
# /content/genres/blues/blues.00044.wav, segment:2
# /content/genres/blues/blues.00044.wav, segment:3
# /content/genres/blues/blues.00044.wav, segment:4
# /content/genres/blues/blues.00044.wav, segment:5
# ...
# /content/genres/rock/rock.00004.wav, segment:2
# /content/genres/rock/rock.00004.wav, segment:3
# /content/genres/rock/rock.00004.wav, segment:4
# /content/genres/rock/rock.00004.wav, segment:5
# /content/genres/rock/rock.00004.wav, segment:6
# /content/genres/rock/rock.00004.wav, segment:7
# /content/genres/rock/rock.00004.wav, segment:8
# /content/genres/rock/rock.00004.wav, segment:9
# /content/genres/rock/rock.00004.wav, segment:10
# /content/genres/rock/rock.00003.wav, segment:1
# /content/genres/rock/rock.00003.wav, segment:2
# /content/genres/rock/rock.00003.wav, segment:3
# /content/genres/rock/rock.00003.wav, segment:4
# /content/genres/rock/rock.00003.wav, segment:5
# /content/genres/rock/rock.00003.wav, segment:6
# /content/genres/rock/rock.00003.wav, segment:7
# /content/genres/rock/rock.00003.wav, segment:8
# /content/genres/rock/rock.00003.wav, segment:9
# /content/genres/rock/rock.00003.wav, segment:10
# /content/genres/rock/rock.00018.wav, segment:1
# /content/genres/rock/rock.00018.wav, segment:2
# /content/genres/rock/rock.00018.wav, segment:3
# /content/genres/rock/rock.00018.wav, segment:4
# /content/genres/rock/rock.00018.wav, segment:5
# /content/genres/rock/rock.00018.wav, segment:6
# /content/genres/rock/rock.00018.wav, segment:7
# /content/genres/rock/rock.00018.wav, segment:8
# /content/genres/rock/rock.00018.wav, segment:9
# /content/genres/rock/rock.00018.wav, segment:10
# /content/genres/rock/rock.00025.wav, segment:1
# /content/genres/rock/rock.00025.wav, segment:2
# /content/genres/rock/rock.00025.wav, segment:3
# /content/genres/rock/rock.00025.wav, segment:4
# /content/genres/rock/rock.00025.wav, segment:5
# /content/genres/rock/rock.00025.wav, segment:6
# /content/genres/rock/rock.00025.wav, segment:7
# /content/genres/rock/rock.00025.wav, segment:8
# /content/genres/rock/rock.00025.wav, segment:9
# /content/genres/rock/rock.00025.wav, segment:10
# /content/genres/rock/rock.00089.wav, segment:1
# /content/genres/rock/rock.00089.wav, segment:2
# /content/genres/rock/rock.00089.wav, segment:3
# /content/genres/rock/rock.00089.wav, segment:4
# /content/genres/rock/rock.00089.wav, segment:5
# /content/genres/rock/rock.00089.wav, segment:6
# /content/genres/rock/rock.00089.wav, segment:7
# /content/genres/rock/rock.00089.wav, segment:8
# /content/genres/rock/rock.00089.wav, segment:9
# /content/genres/rock/rock.00089.wav, segment:10
# /content/genres/rock/rock.00096.wav, segment:1
# /content/genres/rock/rock.00096.wav, segment:2
# /content/genres/rock/rock.00096.wav, segment:3
# /content/genres/rock/rock.00096.wav, segment:4
# /content/genres/rock/rock.00096.wav, segment:5
# /content/genres/rock/rock.00096.wav, segment:6
# /content/genres/rock/rock.00096.wav, segment:7
# /content/genres/rock/rock.00096.wav, segment:8
# /content/genres/rock/rock.00096.wav, segment:9
# /content/genres/rock/rock.00096.wav, segment:10
# /content/genres/rock/rock.00064.wav, segment:1
# /content/genres/rock/rock.00064.wav, segment:2
# /content/genres/rock/rock.00064.wav, segment:3
# /content/genres/rock/rock.00064.wav, segment:4
# /content/genres/rock/rock.00064.wav, segment:5
# /content/genres/rock/rock.00064.wav, segment:6
# /content/genres/rock/rock.00064.wav, segment:7
# /content/genres/rock/rock.00064.wav, segment:8
# /content/genres/rock/rock.00064.wav, segment:9
# /content/genres/rock/rock.00064.wav, segment:10
# /content/genres/rock/rock.00001.wav, segment:1
# /content/genres/rock/rock.00001.wav, segment:2
# /content/genres/rock/rock.00001.wav, segment:3
# /content/genres/rock/rock.00001.wav, segment:4
# /content/genres/rock/rock.00001.wav, segment:5
# /content/genres/rock/rock.00001.wav, segment:6
# /content/genres/rock/rock.00001.wav, segment:7
# /content/genres/rock/rock.00001.wav, segment:8
# /content/genres/rock/rock.00001.wav, segment:9
# /content/genres/rock/rock.00001.wav, segment:10
# /content/genres/rock/rock.00052.wav, segment:1
# /content/genres/rock/rock.00052.wav, segment:2
# /content/genres/rock/rock.00052.wav, segment:3
# /content/genres/rock/rock.00052.wav, segment:4
# /content/genres/rock/rock.00052.wav, segment:5
# /content/genres/rock/rock.00052.wav, segment:6
# /content/genres/rock/rock.00052.wav, segment:7
# /content/genres/rock/rock.00052.wav, segment:8
# /content/genres/rock/rock.00052.wav, segment:9
# /content/genres/rock/rock.00052.wav, segment:10
# /content/genres/rock/rock.00093.wav, segment:1
# /content/genres/rock/rock.00093.wav, segment:2
# /content/genres/rock/rock.00093.wav, segment:3
# /content/genres/rock/rock.00093.wav, segment:4
# /content/genres/rock/rock.00093.wav, segment:5
# /content/genres/rock/rock.00093.wav, segment:6
# /content/genres/rock/rock.00093.wav, segment:7
# /content/genres/rock/rock.00093.wav, segment:8
# /content/genres/rock/rock.00093.wav, segment:9
# /content/genres/rock/rock.00093.wav, segment:10
# /content/genres/rock/rock.00011.wav, segment:1
# /content/genres/rock/rock.00011.wav, segment:2
# /content/genres/rock/rock.00011.wav, segment:3
# /content/genres/rock/rock.00011.wav, segment:4
# /content/genres/rock/rock.00011.wav, segment:5
# /content/genres/rock/rock.00011.wav, segment:6
# /content/genres/rock/rock.00011.wav, segment:7
# /content/genres/rock/rock.00011.wav, segment:8
# /content/genres/rock/rock.00011.wav, segment:9
# /content/genres/rock/rock.00011.wav, segment:10
# /content/genres/rock/rock.00062.wav, segment:1
# /content/genres/rock/rock.00062.wav, segment:2
# /content/genres/rock/rock.00062.wav, segment:3
# /content/genres/rock/rock.00062.wav, segment:4
# /content/genres/rock/rock.00062.wav, segment:5
# /content/genres/rock/rock.00062.wav, segment:6
# /content/genres/rock/rock.00062.wav, segment:7
# /content/genres/rock/rock.00062.wav, segment:8
# /content/genres/rock/rock.00062.wav, segment:9
# /content/genres/rock/rock.00062.wav, segment:10
# /content/genres/rock/rock.00088.wav, segment:1
# /content/genres/rock/rock.00088.wav, segment:2
# /content/genres/rock/rock.00088.wav, segment:3
# /content/genres/rock/rock.00088.wav, segment:4
# /content/genres/rock/rock.00088.wav, segment:5
# /content/genres/rock/rock.00088.wav, segment:6
# /content/genres/rock/rock.00088.wav, segment:7
# /content/genres/rock/rock.00088.wav, segment:8
# /content/genres/rock/rock.00088.wav, segment:9
# /content/genres/rock/rock.00088.wav, segment:10
# /content/genres/rock/rock.00078.wav, segment:1
# /content/genres/rock/rock.00078.wav, segment:2
# /content/genres/rock/rock.00078.wav, segment:3
# /content/genres/rock/rock.00078.wav, segment:4
# /content/genres/rock/rock.00078.wav, segment:5
# /content/genres/rock/rock.00078.wav, segment:6
# /content/genres/rock/rock.00078.wav, segment:7
# /content/genres/rock/rock.00078.wav, segment:8
# /content/genres/rock/rock.00078.wav, segment:9
# /content/genres/rock/rock.00078.wav, segment:10
# /content/genres/rock/rock.00087.wav, segment:1
# /content/genres/rock/rock.00087.wav, segment:2
# /content/genres/rock/rock.00087.wav, segment:3
# /content/genres/rock/rock.00087.wav, segment:4
# /content/genres/rock/rock.00087.wav, segment:5
# /content/genres/rock/rock.00087.wav, segment:6
# /content/genres/rock/rock.00087.wav, segment:7
# /content/genres/rock/rock.00087.wav, segment:8
# /content/genres/rock/rock.00087.wav, segment:9
# /content/genres/rock/rock.00087.wav, segment:10
# /content/genres/rock/rock.00055.wav, segment:1
# /content/genres/rock/rock.00055.wav, segment:2
# /content/genres/rock/rock.00055.wav, segment:3
# /content/genres/rock/rock.00055.wav, segment:4
# /content/genres/rock/rock.00055.wav, segment:5
# /content/genres/rock/rock.00055.wav, segment:6
# /content/genres/rock/rock.00055.wav, segment:7
# /content/genres/rock/rock.00055.wav, segment:8
# /content/genres/rock/rock.00055.wav, segment:9
# /content/genres/rock/rock.00055.wav, segment:10
# /content/genres/rock/rock.00057.wav, segment:1
# /content/genres/rock/rock.00057.wav, segment:2
# /content/genres/rock/rock.00057.wav, segment:3
# /content/genres/rock/rock.00057.wav, segment:4
# /content/genres/rock/rock.00057.wav, segment:5
# /content/genres/rock/rock.00057.wav, segment:6
# /content/genres/rock/rock.00057.wav, segment:7
# /content/genres/rock/rock.00057.wav, segment:8
# /content/genres/rock/rock.00057.wav, segment:9
# /content/genres/rock/rock.00057.wav, segment:10
# /content/genres/rock/rock.00073.wav, segment:1
# /content/genres/rock/rock.00073.wav, segment:2
# /content/genres/rock/rock.00073.wav, segment:3
# /content/genres/rock/rock.00073.wav, segment:4
# /content/genres/rock/rock.00073.wav, segment:5
# /content/genres/rock/rock.00073.wav, segment:6
# /content/genres/rock/rock.00073.wav, segment:7
# /content/genres/rock/rock.00073.wav, segment:8
# /content/genres/rock/rock.00073.wav, segment:9
# /content/genres/rock/rock.00073.wav, segment:10
# /content/genres/rock/rock.00040.wav, segment:1
# /content/genres/rock/rock.00040.wav, segment:2
# /content/genres/rock/rock.00040.wav, segment:3
# /content/genres/rock/rock.00040.wav, segment:4
# /content/genres/rock/rock.00040.wav, segment:5
# /content/genres/rock/rock.00040.wav, segment:6
# /content/genres/rock/rock.00040.wav, segment:7
# /content/genres/rock/rock.00040.wav, segment:8
# /content/genres/rock/rock.00040.wav, segment:9
# /content/genres/rock/rock.00040.wav, segment:10
# /content/genres/rock/rock.00020.wav, segment:1
# /content/genres/rock/rock.00020.wav, segment:2
# /content/genres/rock/rock.00020.wav, segment:3
# /content/genres/rock/rock.00020.wav, segment:4
# /content/genres/rock/rock.00020.wav, segment:5
# /content/genres/rock/rock.00020.wav, segment:6
# /content/genres/rock/rock.00020.wav, segment:7
# /content/genres/rock/rock.00020.wav, segment:8
# /content/genres/rock/rock.00020.wav, segment:9
# /content/genres/rock/rock.00020.wav, segment:10
# /content/genres/rock/rock.00006.wav, segment:1
# /content/genres/rock/rock.00006.wav, segment:2
# /content/genres/rock/rock.00006.wav, segment:3
# /content/genres/rock/rock.00006.wav, segment:4
# /content/genres/rock/rock.00006.wav, segment:5
# /content/genres/rock/rock.00006.wav, segment:6
# /content/genres/rock/rock.00006.wav, segment:7
# /content/genres/rock/rock.00006.wav, segment:8
# /content/genres/rock/rock.00006.wav, segment:9
# /content/genres/rock/rock.00006.wav, segment:10
# /content/genres/rock/rock.00021.wav, segment:1
# /content/genres/rock/rock.00021.wav, segment:2
# /content/genres/rock/rock.00021.wav, segment:3
# /content/genres/rock/rock.00021.wav, segment:4
# /content/genres/rock/rock.00021.wav, segment:5
# /content/genres/rock/rock.00021.wav, segment:6
# /content/genres/rock/rock.00021.wav, segment:7
# /content/genres/rock/rock.00021.wav, segment:8
# /content/genres/rock/rock.00021.wav, segment:9
# /content/genres/rock/rock.00021.wav, segment:10
# /content/genres/rock/rock.00045.wav, segment:1
# /content/genres/rock/rock.00045.wav, segment:2
# /content/genres/rock/rock.00045.wav, segment:3
# /content/genres/rock/rock.00045.wav, segment:4
# /content/genres/rock/rock.00045.wav, segment:5
# /content/genres/rock/rock.00045.wav, segment:6
# /content/genres/rock/rock.00045.wav, segment:7
# /content/genres/rock/rock.00045.wav, segment:8
# /content/genres/rock/rock.00045.wav, segment:9
# /content/genres/rock/rock.00045.wav, segment:10
# /content/genres/rock/rock.00060.wav, segment:1
# /content/genres/rock/rock.00060.wav, segment:2
# /content/genres/rock/rock.00060.wav, segment:3
# /content/genres/rock/rock.00060.wav, segment:4
# /content/genres/rock/rock.00060.wav, segment:5
# /content/genres/rock/rock.00060.wav, segment:6
# /content/genres/rock/rock.00060.wav, segment:7
# /content/genres/rock/rock.00060.wav, segment:8
# /content/genres/rock/rock.00060.wav, segment:9
# /content/genres/rock/rock.00060.wav, segment:10
# /content/genres/rock/rock.00009.wav, segment:1
# /content/genres/rock/rock.00009.wav, segment:2
# /content/genres/rock/rock.00009.wav, segment:3
# /content/genres/rock/rock.00009.wav, segment:4
# /content/genres/rock/rock.00009.wav, segment:5
# /content/genres/rock/rock.00009.wav, segment:6
# /content/genres/rock/rock.00009.wav, segment:7
# /content/genres/rock/rock.00009.wav, segment:8
# /content/genres/rock/rock.00009.wav, segment:9
# /content/genres/rock/rock.00009.wav, segment:10
# /content/genres/rock/rock.00014.wav, segment:1
# /content/genres/rock/rock.00014.wav, segment:2
# /content/genres/rock/rock.00014.wav, segment:3
# /content/genres/rock/rock.00014.wav, segment:4
# /content/genres/rock/rock.00014.wav, segment:5
# /content/genres/rock/rock.00014.wav, segment:6
# /content/genres/rock/rock.00014.wav, segment:7
# /content/genres/rock/rock.00014.wav, segment:8
# /content/genres/rock/rock.00014.wav, segment:9
# /content/genres/rock/rock.00014.wav, segment:10
# /content/genres/rock/rock.00084.wav, segment:1
# /content/genres/rock/rock.00084.wav, segment:2
# /content/genres/rock/rock.00084.wav, segment:3
# /content/genres/rock/rock.00084.wav, segment:4
# /content/genres/rock/rock.00084.wav, segment:5
# /content/genres/rock/rock.00084.wav, segment:6
# /content/genres/rock/rock.00084.wav, segment:7
# /content/genres/rock/rock.00084.wav, segment:8
# /content/genres/rock/rock.00084.wav, segment:9
# /content/genres/rock/rock.00084.wav, segment:10
# /content/genres/rock/rock.00059.wav, segment:1
# /content/genres/rock/rock.00059.wav, segment:2
# /content/genres/rock/rock.00059.wav, segment:3
# /content/genres/rock/rock.00059.wav, segment:4
# /content/genres/rock/rock.00059.wav, segment:5
# /content/genres/rock/rock.00059.wav, segment:6
# /content/genres/rock/rock.00059.wav, segment:7
# /content/genres/rock/rock.00059.wav, segment:8
# /content/genres/rock/rock.00059.wav, segment:9
# /content/genres/rock/rock.00059.wav, segment:10
# /content/genres/rock/rock.00022.wav, segment:1
# /content/genres/rock/rock.00022.wav, segment:2
# /content/genres/rock/rock.00022.wav, segment:3
# /content/genres/rock/rock.00022.wav, segment:4
# /content/genres/rock/rock.00022.wav, segment:5
# /content/genres/rock/rock.00022.wav, segment:6
# /content/genres/rock/rock.00022.wav, segment:7
# /content/genres/rock/rock.00022.wav, segment:8
# /content/genres/rock/rock.00022.wav, segment:9
# /content/genres/rock/rock.00022.wav, segment:10
# /content/genres/rock/rock.00068.wav, segment:1
# /content/genres/rock/rock.00068.wav, segment:2
# /content/genres/rock/rock.00068.wav, segment:3
# /content/genres/rock/rock.00068.wav, segment:4
# /content/genres/rock/rock.00068.wav, segment:5
# /content/genres/rock/rock.00068.wav, segment:6
# /content/genres/rock/rock.00068.wav, segment:7
# /content/genres/rock/rock.00068.wav, segment:8
# /content/genres/rock/rock.00068.wav, segment:9
# /content/genres/rock/rock.00068.wav, segment:10
# /content/genres/rock/rock.00039.wav, segment:1
# /content/genres/rock/rock.00039.wav, segment:2
# /content/genres/rock/rock.00039.wav, segment:3
# /content/genres/rock/rock.00039.wav, segment:4
# /content/genres/rock/rock.00039.wav, segment:5
# /content/genres/rock/rock.00039.wav, segment:6
# /content/genres/rock/rock.00039.wav, segment:7
# /content/genres/rock/rock.00039.wav, segment:8
# /content/genres/rock/rock.00039.wav, segment:9
# /content/genres/rock/rock.00039.wav, segment:10
# /content/genres/rock/rock.00017.wav, segment:1
# /content/genres/rock/rock.00017.wav, segment:2
# /content/genres/rock/rock.00017.wav, segment:3
# /content/genres/rock/rock.00017.wav, segment:4
# /content/genres/rock/rock.00017.wav, segment:5
# /content/genres/rock/rock.00017.wav, segment:6
# /content/genres/rock/rock.00017.wav, segment:7
# /content/genres/rock/rock.00017.wav, segment:8
# /content/genres/rock/rock.00017.wav, segment:9
# /content/genres/rock/rock.00017.wav, segment:10
# /content/genres/rock/rock.00012.wav, segment:1
# /content/genres/rock/rock.00012.wav, segment:2
# /content/genres/rock/rock.00012.wav, segment:3
# /content/genres/rock/rock.00012.wav, segment:4
# /content/genres/rock/rock.00012.wav, segment:5
# /content/genres/rock/rock.00012.wav, segment:6
# /content/genres/rock/rock.00012.wav, segment:7
# /content/genres/rock/rock.00012.wav, segment:8
# /content/genres/rock/rock.00012.wav, segment:9
# /content/genres/rock/rock.00012.wav, segment:10
# /content/genres/rock/rock.00069.wav, segment:1
# /content/genres/rock/rock.00069.wav, segment:2
# /content/genres/rock/rock.00069.wav, segment:3
# /content/genres/rock/rock.00069.wav, segment:4
# /content/genres/rock/rock.00069.wav, segment:5
# /content/genres/rock/rock.00069.wav, segment:6
# /content/genres/rock/rock.00069.wav, segment:7
# /content/genres/rock/rock.00069.wav, segment:8
# /content/genres/rock/rock.00069.wav, segment:9
# /content/genres/rock/rock.00069.wav, segment:10

# %% [markdown]
# #Implementing CNN

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "/content/genres/data_10.json"


def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y





def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model

    
if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()
    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    
    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 128, 11, 32)       320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 64, 6, 32)         0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 64, 6, 32)         128
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 62, 4, 32)         9248
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 31, 2, 32)         0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 31, 2, 32)         128
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 30, 1, 32)         4128
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 15, 1, 32)         0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 15, 1, 32)         128
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 480)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                30784
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                650
# =================================================================
# Total params: 45,514
# Trainable params: 45,322
# Non-trainable params: 192
# _________________________________________________________________
# Train on 5997 samples, validate on 1500 samples
# Epoch 1/30
# 5997/5997 [==============================] - 2s 264us/sample - loss: 2.3311 - acc: 0.2303 - val_loss: 1.7871 - val_acc: 0.3553
# Epoch 2/30
# 5997/5997 [==============================] - 1s 200us/sample - loss: 1.8097 - acc: 0.3670 - val_loss: 1.5156 - val_acc: 0.4407
# Epoch 3/30
# 5997/5997 [==============================] - 1s 206us/sample - loss: 1.6139 - acc: 0.4245 - val_loss: 1.4043 - val_acc: 0.4840
# Epoch 4/30
# 5997/5997 [==============================] - 1s 190us/sample - loss: 1.4833 - acc: 0.4691 - val_loss: 1.3226 - val_acc: 0.5007
# Epoch 5/30
# 5997/5997 [==============================] - 1s 194us/sample - loss: 1.4052 - acc: 0.4949 - val_loss: 1.2580 - val_acc: 0.5407
# Epoch 6/30
# 5997/5997 [==============================] - 1s 190us/sample - loss: 1.3093 - acc: 0.5231 - val_loss: 1.1913 - val_acc: 0.5633
# Epoch 7/30
# 5997/5997 [==============================] - 1s 190us/sample - loss: 1.2768 - acc: 0.5386 - val_loss: 1.1573 - val_acc: 0.5813
# Epoch 8/30
# 5997/5997 [==============================] - 1s 191us/sample - loss: 1.2161 - acc: 0.5661 - val_loss: 1.1197 - val_acc: 0.5947
# Epoch 9/30
# 5997/5997 [==============================] - 1s 194us/sample - loss: 1.1485 - acc: 0.5835 - val_loss: 1.0839 - val_acc: 0.6160
# Epoch 10/30
# 5997/5997 [==============================] - 1s 191us/sample - loss: 1.1162 - acc: 0.6000 - val_loss: 1.0558 - val_acc: 0.6340
# Epoch 11/30
# 5997/5997 [==============================] - 1s 197us/sample - loss: 1.0809 - acc: 0.6168 - val_loss: 1.0385 - val_acc: 0.6327
# Epoch 12/30
# 5997/5997 [==============================] - 1s 218us/sample - loss: 1.0462 - acc: 0.6353 - val_loss: 0.9985 - val_acc: 0.6433
# Epoch 13/30
# 5997/5997 [==============================] - 1s 194us/sample - loss: 1.0042 - acc: 0.6382 - val_loss: 0.9884 - val_acc: 0.6540
# Epoch 14/30
# 5997/5997 [==============================] - 1s 190us/sample - loss: 0.9571 - acc: 0.6628 - val_loss: 0.9877 - val_acc: 0.6420
# Epoch 15/30
# 5997/5997 [==============================] - 1s 192us/sample - loss: 0.9643 - acc: 0.6617 - val_loss: 0.9710 - val_acc: 0.6627
# Epoch 16/30
# 5997/5997 [==============================] - 1s 192us/sample - loss: 0.9166 - acc: 0.6743 - val_loss: 0.9748 - val_acc: 0.6573
# Epoch 17/30
# 5997/5997 [==============================] - 1s 188us/sample - loss: 0.9082 - acc: 0.6770 - val_loss: 0.9324 - val_acc: 0.6700
# Epoch 18/30
# 5997/5997 [==============================] - 1s 192us/sample - loss: 0.8678 - acc: 0.6948 - val_loss: 0.9039 - val_acc: 0.6873
# Epoch 19/30
# 5997/5997 [==============================] - 1s 194us/sample - loss: 0.8470 - acc: 0.6942 - val_loss: 0.9165 - val_acc: 0.6847
# Epoch 20/30
# 5997/5997 [==============================] - 1s 194us/sample - loss: 0.8332 - acc: 0.7085 - val_loss: 0.8945 - val_acc: 0.6933
# Epoch 21/30
# 5997/5997 [==============================] - 1s 215us/sample - loss: 0.8031 - acc: 0.7165 - val_loss: 0.8746 - val_acc: 0.6960
# Epoch 22/30
# 5997/5997 [==============================] - 1s 191us/sample - loss: 0.7950 - acc: 0.7212 - val_loss: 0.8768 - val_acc: 0.7020
# Epoch 23/30
# 5997/5997 [==============================] - 1s 186us/sample - loss: 0.7665 - acc: 0.7300 - val_loss: 0.8720 - val_acc: 0.7040
# Epoch 24/30
# 5997/5997 [==============================] - 1s 191us/sample - loss: 0.7509 - acc: 0.7382 - val_loss: 0.8553 - val_acc: 0.7067
# Epoch 25/30
# 5997/5997 [==============================] - 1s 196us/sample - loss: 0.7355 - acc: 0.7442 - val_loss: 0.8661 - val_acc: 0.6960
# Epoch 26/30
# 5997/5997 [==============================] - 1s 194us/sample - loss: 0.7179 - acc: 0.7460 - val_loss: 0.8351 - val_acc: 0.7087
# Epoch 27/30
# 5997/5997 [==============================] - 1s 191us/sample - loss: 0.7009 - acc: 0.7537 - val_loss: 0.8582 - val_acc: 0.7087
# Epoch 28/30
# 5997/5997 [==============================] - 1s 196us/sample - loss: 0.6867 - acc: 0.7550 - val_loss: 0.8835 - val_acc: 0.7020
# Epoch 29/30
# 5997/5997 [==============================] - 1s 197us/sample - loss: 0.6790 - acc: 0.7582 - val_loss: 0.8639 - val_acc: 0.7093
# Epoch 30/30
# 5997/5997 [==============================] - 1s 188us/sample - loss: 0.6553 - acc: 0.7677 - val_loss: 0.8188 - val_acc: 0.7100
# 2499/2499 - 0s - loss: 0.7453 - acc: 0.7379
#
# Test accuracy: 0.73789513

# %%
X_train.shape
# Out:
# (5997, 130, 13, 1)

# %% [markdown]
# #Predicting own DATASET

# %% [markdown]
# **Exatracting mfcc from input file**

# %%
num_segments=5
num_mfcc=13 
n_fft=2048 
hop_length=512
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = 22050*30
samples_per_segment = int(SAMPLES_PER_TRACK /5)
num_mfcc_vectors_per_segment = 130
MFCC=[]


  # load audio fil
file_path ="/content/genres/blues/blues.00003.wav"
signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

# process all segments of audio file
for d in range(5):

  # calculate start and finish sample for current segment
  start = samples_per_segment * d
  finish = start + samples_per_segment
  start=int(start/2)
  finish=int(finish/2)
  # extract mfcc
  mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
  mfcc = mfcc.T

# %% [markdown]
# **Function for the prediction**

# %%
def predict(model, X):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X=X[..., np.newaxis]
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    return predicted_index 

if __name__ == "__main__":
  predict(model,mfcc)
print(predicted_index)
# Out:
# [8]
